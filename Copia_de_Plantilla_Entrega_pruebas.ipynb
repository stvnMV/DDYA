# %% [markdown]
# <a href="https://colab.research.google.com/github/stvnMV/DDYA/blob/Semana-4/Copia_de_Plantilla_Entrega_pruebas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
nombre_estudiante = "" # @param {"type":"string"}
carnet = None # @param {"type":"integer"}

# %% [markdown]
# ## 1) Descripción del problema
# Una tienda en Colombia necesita desarrollar un programa que calcule la menor cantidad de monedas necesarias para entregar un cambio determinado a un cliente.
#
# La tienda dispone de las siguientes monedas:
#
# monedas = [50, 100, 200, 500, 1000]
# El usuario deberá ingresar el valor del cambio que necesita entregar.

# %% [markdown]
# ## 2) Requerimientos
# ##-Requerimientos funcionales
#
# RQF01 Leer el valor de cambio a entregar
#
# RQF02 Calcular el valor de monedas a dar
#
# RQF03 Mostrar El valor de monedas a dar
# ##-Requerimientos no funcionales
#
# <br>RQNF 01 (Eficiencia):Al estar usando métodos de programacoin dinamica el codigo reduce drasticamente su complejidad gracias a estrategias como la memoizacion, en consecuencia el código reduce en gran parte su complejidad, por lo cual ocupa menos recursos
#
# <br>RQNF 02 (Mantenibilidad): Ya que el código es modular, es más fácil adaptarlo, modificarlo
#
# <br>RQNF 03 (Corrección): Ya que el código es modular, permite ver las funciónes facilmente si hay un error
#
# <br>RQNF 04 (Programar en Python): Programamos en Python porque el lenguaje Python es un lenguaje facil de comprender el cual se usa más que todo en programas de datos

# %% [markdown]
# ## 3) Historias de usuario
# HU 01 : Leer el cambio a dar producto
#
# RQF01 <br>Entradas <br>→ Cambio a dar
#
# Salidas<br> → un mensaje que dice "Dato valido"<br>
# → Un mensaje que dice "Dato invalido, por favor asegurese de ingresar solo: <br>- Numeros enteros <br>- Numeros positivos <br>- No dejar el campo vacio  <br>- No ingresar letras ni simbolos <br>- Introducir un solo numero <br>- No usar espacios, comas o cualquier otro caracter excepto puntos
#
# CA <br>→ número positivo
#
# CE <br>→ Si no es número <br>→ Si es un número negativo <br>→ Si el numero tiene un espacion o caracter adicional excepto puntos
#
# <br>HU 02: Calcular monedas a dar
#
# RQF02
#
# Entradas <br>→ Ninguna
#
# Salidas <br> → Ninguna
#
# CA <br>→ número positivo
#
# CE <br>→ Si no es número <br>→ Si es un número negativo<br>→ Si el numero tiene un espacion o caracter adicional excepto puntos
#
#
# <br>HU 03: Mostrar si la cantidad de monedas es correcta
#
# RQF03
#
# Entradas<br> → Ninguna
#
# Salidas <br>→ Bien <br>→Mal
#
#
# CA <br>→ número positivo
#
# CE <br>→ Si no es número <br>→ Si es un número negativo<br>→ Si el numero tiene un espacion o caracter adicional excepto puntos

# %% [markdown]
# ## 4) Diagramas de flujo ![Blank diagram (3).png](data:image/png;base64,...)
# En este diagrama de flujo se puede evidenciar todo el proceso del codigo, comenzando por analizar los datos y verificar que sean validos, para despues calcular la cantidad de monedas minimas requeridas, y por ultimo mostrar dicho verificar si el resultado es el esperado

# %% [markdown]
# ## 5) Diagramas de secuencia
# ![Blank diagram (4).png](data:image/png;base64,...)
#
# En el diagrama de secuencia se muestra como interactúan los actores en el proceso, en este caso los actores es el usuario, la función test(a,b) con la de compr(a) y finalmente la programación dinámica

# %% [markdown]
# ## 6) Diagramas de casos de uso
# ![Blank diagram (2).png](data:image/png;base64,...)En este diagrama de uso se evidencia como el usuario interactua con el sistema, empezando por la solicitud de datos, para continuar con el procesamiento de estos, y por ultimo mostrar el resultado esperado

# %% [markdown]
# ## 7) Análisis de complejidad
# ![geogebra-export (1).png](data:image/png;base64,...)
# T(n)=O(n^2)

# %% [markdown]
# ## 8) Código funcional **[10 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
from IPython.core.builtin_trap import BuiltinUndefined
import time
import matplotlib.pyplot as plt
def compr(a):
    try:
        val = int(a)

        if val <= 0:
            raise ValueError
        print("Dato valido")
        return 1

    except ValueError:
        print("Dato invalido, por favor asegurese de ingresar solo: \n- Numeros enteros \n- Numeros positivos \n- No dejar el campo vacio\n- No ingresar letras ni simbolos\n- Introducir un solo numero\n- No usar espacios, comas o cualquier otro caracter")
        return 0

def test(a,b):
    monedas = [50, 100, 200, 500, 1000]
    ctrl=compr(a)
    if ctrl == 0:
      return
    a=((a+25)//50)*50
    pd = [9999999] * (a + 1)
    pd[0] = 0
    for i in range(1, a + 1):
          for moneda in monedas:
              if moneda <= i:
                pd[i] = min(pd[i],pd[i - moneda] + 1)
    if b == pd[a]:
      return print("bien")
    else:
      return print("mal, el valor debe ser:",pd[a])

# %% [markdown]
# ## 9) pruebas **[15 pts]**

# %% [markdown]
# ## Pruebas de enunciado
#
# Ingrese el valor del cambio: 1850
# El programa debe determinar cuál es la menor cantidad de monedas necesaria para completar exactamente ese valor.
#
# Una posible solución sería:
#
# 1000 + 500 + 200 + 100 + 50 = 1850
# Por lo tanto:
#
# Cantidad mínima de monedas: 5
#
# Input=1850
# Output=5

# %%
input, output = 1850, 5
test(input,output)
# Out:
# Dato valido
# bien

# %% [markdown]
# ## Pruebas propias
# Input=2523
# Output=3

# %%
input, output = 2523,3
test(input,output)
# Out:
# Dato valido
# bien

# %% [markdown]
# ## Pruebas de Desempeño
# Qué va aquí?
#
# Medición empírica del tiempo de ejecución.
#
# Gráfica de comportamiento.
#
# Relación entre la gráfica obtenida y el análisis de complejidad teórico.
#
# #### Código base para benchmarking

# %%
# Calcula el tiempo de ejecucion con base a diferentes tamaños de la entrada
# y nos da una lista de resultados, cada resultado contiene el tamaño de la entrada
# y el tiempo de ejecucion
# TENER EN CUENTA ESTAS ENTRADAS PUEDEN VARIAR SEGÚN EL PROBLEMA


def bench(n: int, step: int = 1) -> list[tuple[int, float]]:
    print("Generando datos ...", end='')
    from random import randint
    import time
    results: list[tuple[int, float]] = []


    # AJUSTAR LAS ENTRADAS SEGÚN EL PROBLEMA
    for size in range(1, n, step):
        input = size

        ti = time.perf_counter()

        tf = time.perf_counter()


        delta = (tf - ti) * 1000
        print(".", end="")
        results.append((size, delta))
    return results


# === CODIGO PARA DIBUJAR ===


def dibujar(x, y, dimensiones=(7, 5)):
    assert len(x) == len(y)
    import matplotlib.pyplot as plt
    plt.figure(figsize=dimensiones)
    plt.plot(x, y)
    plt.show()


# === LLAMADO ===
tiempos = bench(10, step=1)


x = [size for size, timing in tiempos]
y = [timing for size, timing in tiempos]


dibujar(x, y)
# Out:
# Generando datos ............
