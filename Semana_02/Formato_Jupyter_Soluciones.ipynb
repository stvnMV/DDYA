# %% [markdown]
# # DISEÑO DE DATOS Y ALGORITMOS

# %%
# @title Ingrese datos
nombre_estudiante = "" # @param {"type":"string"}
carnet = None # @param {"type":"integer"}

# %% [markdown]
# ## Enunciado
# <h3>Problema de laboratorio semana 2</h3>
#   Una tienda necesita organizar los precios de sus productos. La cantidad de productos puede variar, por lo que el usuario deberá indicar cuántos precios desea registrar.
#
#   El programa debe solicitar:
#
#   La cantidad de productos, representada por n.
#   El precio de cada uno de los productos.
#   El tipo de ordenamiento que se desea mostrar.
#   Después de ingresar los datos, el programa deberá utilizar el algoritmo Insertion Sort para organizar los precios.
#
#   Punto 1. Orden ascendente
#   Ordenar los precios desde el menor hasta el mayor, con el fin de mostrar primero los productos más económicos.
#
#   Punto 2. Orden descendente
#   Ordenar los precios desde el mayor hasta el menor, con el fin de mostrar primero los productos más costosos.
#
#
# https://teams.microsoft.com

# %% [markdown]
# # Especificacion

# %% [markdown]
# RQF 01: Leer la cantidad del producto
#
# RQF 02: Leer el precio de cada producto
#
# RQF 03: Leer el tipo de ordenamiento que se desea mostrar
#
#
# RQNF 01 (Eficiencia): El código es eficiente ya que es modular, es decir que los datos obtenidos no se van a alterar
#
# RQNF 02 (Mantenibilidad): Ya que el código es modular, es más fácil adaptarlo, modificarlo
#
# RQNF 03 (Corrección): Ya que el código es modular, permite ver las funciónes facilmente si hay un error
#
# RQNF 04 (Programar en Python): Programamos en Python porque el lenguaje Python es un lenguaje facil de comprender el cual se usa más que todo en programas de datos
#
#
# HU 01 : Leer la cantidad del producto
#
#     RQF01
#     Entradas → cantidad del producto
#     Salidas → Un mensaje que dice "cantidad guardada"
#             → Un mensaje que dice "Digite números mayores a 0"
#     CA → número positivo
#     CE → Si no es número
#        → Si es un número negativo
#
#
# HU 02: Leer el precio del producto
#
#     RQF02
#     Entradas → precio del producto
#     Salidas → Un mensaje que dice "precio guardado"
#             → Un mensaje que dice "Digite números mayores a 0"
#     CA → número positivo
#     CE → Si no es número
#        → Si es un número negativo
#
# HU 03: Leer el tipo de ordenamiento que se desea mostrar
#
#     RQF03
#     Entradas →  la palabra "ascendente"
#              →  la palabra "descendente"
#     Salidas → Un mensaje mostrando el ordenamiento de la lista de productos
#             → Un mensaje diciendo"Opción incorrecta"
#     CA → la palabra "ascendente" ó la palabra "descendente"
#     CE → Si no es la palabra "ascendente" ó "descendente"

# %% [markdown]
# # Diseño

# %% [markdown]
# <h2>Tabla de complejidad y grafica</h2>
#
# ![Untitled.jpg](data:image/jpeg;base64,...)![geogebra-export.png](data:image/png;base64,...)
#
# <h2>Diagrama de flujo: ordenamiento de precios</h2>
#
# ![Blank diagram.png](data:image/png;base64,...)

# %% [markdown]
# # Codigo

# %%
def ord_asc(prec,n):
    for i in range(1, n):
        key = prec[i]
        j = i - 1
        while j >= 0 and key < prec[j]:
            prec[j + 1] = prec[j]
            j= j-1
        prec[j + 1] = key
    return prec

def ord_des(prec,n):
    for i in range(1, n):
        key = prec[i]
        j = i - 1
        while j >= 0 and key > prec[j]:
            prec[j + 1] = prec[j]
            j= j-1
        prec[j + 1] = key
    return prec

def compr(a):
    try:
        val=float(a)
        if val <= 0:
            raise ValueError
        print("Cantidad guardada")
        return 1
    except ValueError:
        print("Digite solo numeros mayores a cero")
        return 0


def main():
    n=0
    b=0
    print("Bienvenido al programa")
    while b==0:
        n=input("Digite la cantida de productos que quiere ingresar:")
        b=compr(n)
    n=int(n)

    prec=[0 for c in range (n)]
    c=0
    while c<n:
        prec[c]=input("Digite el precio del producto #"+str(c+1)+":")
        if compr(prec[c])==1:
            prec[c]=float(prec[c])
            c+=1

    print("_____MENU_____")
    print("\tIngrese como desea Ordenar el dato \t\n1.Orden ascendente \t\n2.Orden descendente")
    b=0
    while b==0:
        opc=input("_")
        b=compr(opc)
        if opc!="1" and opc!="2":
            b=0
            print("Dato invalido")
    if int(opc)==1:
        print(ord_asc(prec,n))
    elif int(opc)==2:
        print(ord_des(prec,n))
main()
# Out:
# Bienvenido al programa

# %% [markdown]
# # Pruebas

# %%
def test(input, expected_output):
  # CALCULE LA SOLUCION (asignela a got_output)
  got_output =input
  assert got_output == expected_output, f"se obtuvo {got_output}, pero se esperaba {expected_output}"
  print(f"Paso caso de prueba {input} -> {expected_output}")

# %% [markdown]
# ## Pruebas de enunciado
#
# ¿Qué va aquí?
#
# Casos de prueba proporcionados por el enunciado.
#
# Entrada usada.
#
# Salida esperada.
#
# Salida obtenida.

# %%
input, output = "123", "123"
test(input,output)
# Out:
# Paso caso de prueba 123 -> 123

# %% [markdown]
# ## Pruebas propias
# ¿Qué va aquí?
#
# Casos creados por usted.
#
# Casos tomados de [UDebug](https://www.udebug.com/) (si aplica).

# %%
input, output = "123", "123"
test(input,output)
# Out:
# Paso caso de prueba 123 -> 123

# %% [markdown]
# ## Pruebas de Desempeño
# Qué va aquí?
#
# Medición empírica del tiempo de ejecución.
#
# Gráfica de comportamiento.
#
# Relación entre la gráfica obtenida y el análisis de complejidad teórico.
#
# #### Código base para benchmarking

# %%
# Calcula el tiempo de ejecucion con base a diferentes tamaños de la entrada
# y nos da una lista de resultados, cada resultado contiene el tamaño de la entrada
# y el tiempo de ejecucion
# TENER EN CUENTA ESTAS ENTRADAS PUEDEN VARIAR SEGÚN EL PROBLEMA


def bench(n: int, step: int = 1) -> list[tuple[int, float]]:
    print("Generando datos ...", end='')
    from random import randint
    import time
    results: list[tuple[int, float]] = []


    # AJUSTAR LAS ENTRADAS SEGÚN EL PROBLEMA
    for size in range(1, n, step):
        input = size

        ti = time.perf_counter()
        output = input # Ajustar a su función
        tf = time.perf_counter()


        delta = (tf - ti) * 1000
        print(".", end="")
        results.append((size, delta))
    return results


# === CODIGO PARA DIBUJAR ===


def dibujar(x, y, dimensiones=(7, 5)):
    assert len(x) == len(y)
    import matplotlib.pyplot as plt
    plt.figure(figsize=dimensiones)
    plt.plot(x, y)
    plt.show()


# === LLAMADO ===
tiempos = bench(10, step=1)


x = [size for size, timing in tiempos]
y = [timing for size, timing in tiempos]


dibujar(x, y)
# Out:
# Generando datos ............

# %% [markdown]
# ### Interpretación
#
# Explique:
#
# Qué comportamiento muestra la gráfica.
#
# Cómo se relaciona con su análisis de complejidad.

# %% [markdown]
# # Retrospectiva IA
# ¿Qué va aquí?
#
# Reflexión personal sobre el uso de IA:
#
# ¿En qué le ayudó la IA?
#
# ¿Qué parte del problema no entendía al inicio?
#
# ¿Qué aprendió realmente?
#
# No es una confesión, es una reflexión de aprendizaje.

# %% [markdown]
# # Juez
#
# ### Código Juez
#
# Incluya el código final enviado al juez, exactamente como se entregó:

# %%
#from sys import stdin

def main():
    pass


if __name__ == "__main__":
    main()

# %% [markdown]
# ### Evidencia Juez
# Capture de pantalla del resultado Accepted / Correct.
#
# Incluya claramente:
#
# Nombre del problema
#
# Estado
#
# Fecha (si es visible)
